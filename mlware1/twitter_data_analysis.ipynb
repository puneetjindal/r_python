# %%
import pandas as pd

# %%
raw_text = pd.read_csv('train_MLWARE1.csv')

# %%
raw_text
# Out:
#                ID                                              tweet  \
# 0      T000452358                        b'oh yea that makes sense '
# 1      T000452359  Estas enfermedad a un cargo poltico tu como pb...
# 2      T000452360  @alleygirl2409 until i\'m and all the old men ...
# 3      T000452361  b"@sarinas it had been chanted peacefully you ...
# 4      T000452362  b"there's nothing like being on vacation and h...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364  b'May I block you too RT But what if he or she...
# 7      T000452365  b'Wow I really forgot how much I love the traf...
# 8      T000452366  b'How perfect my internet just went out thanks...
# 9      T000452367                    b'Love having no voice $$SAR$$'
# 10     T000452368  b'Apparently i have to sacrifice a goat and do...
# 11     T000452369                            b'Drivers Ed Yay boring
# 12     T000452370  b'I like how he gets all the credit and not do...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-54ea10bf7c26> in <module>()
# ----> 1 from sklearn.feature_extraction.text import CountVectorizer
#
# c:\python27\lib\site-packages\sklearn\__init__.py in <module>()
#      55 else:
#      56     from . import __check_build
# ---> 57     from .base import clone
#      58     __check_build  # avoid flakes unused variable error
#      59
#
# c:\python27\lib\site-packages\sklearn\base.py in <module>()
#       8
#       9 import numpy as np
# ---> 10 from scipy import sparse
#      11 from .externals import six
#      12 from .utils.fixes import signature
#
# c:\python27\lib\site-packages\scipy\__init__.py in <module>()
#      59 __all__ = ['test']
#      60
# ---> 61 from numpy._distributor_init import NUMPY_MKL  # requires numpy+mkl
#      62
#      63 from numpy import show_config as show_numpy_config
#
# ...

# %%
#Preprocessing Your Data with nltk and scikit-learn and re 
#Tokenizing text with scikit-learn
#Removing stopwords such as “that” or “and”,
#Stemming, which you use to extract the root of words. This can be done with the help of a dictionary or with linguistic rules or algorithms such as Porter’s Algorithm
#Create a document term matrix: elements in this matrix represent the occurrence of a term (a word or an n-gram) in a document of the corpus.
#use a histogram to visualize the frequency of the words in your corpus.
#correlation between two or more terms in your corpus.
#use wordcloud library in python
#document term matrix or the histogram that you have a lot of sparse words, you can decide to remove them from your corpus.
